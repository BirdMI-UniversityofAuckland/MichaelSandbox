# %% [markdown]
# **MicSpeakerCheck,**
#
# This program is designed to compare the transition of a digital sound with a sound that has been through a speaker, and recorded via a microphone. Multiple sounds will be tested, and different hardwares (speakers and microphones) will also be tested.
#
# **The program works as follows,**
#
# A selected sound is played through the speaker, and recorded simultaneously. The two raw traces of the two sounds are saved to wav files, where SAP-2011 is used to calculate characteristic sound features and exported to .xls files containing the raw features. These raw features are then loaded back so that the second half of the program can analyse: correlated to give a correlation coefficient.
# These coefficients can then be plotted to form a population distribution of trials, and are compared to the population distributions of 'similar' picked motifs from the song bird.
# These distributions can then be visualised using matplotlib.
#
# By analysising the overlap of the distributions between the birds own song, and the differences between the speakers, we should get a realistic idea if the playback from the speaker will be faithful enough at reproducing birds own song that it can be used in our BMI.
#
# Written by Michael Barnett
# Started 5th Aug 2015
#
# ** Movement of external data: **
#
# The **working_directory** will consist of 3 folders,
#
# **1. WAV Library,**this contains all sounds we intend to test, eg Noise, Syllables, Motifs, pure tones, ascending tones.
#
# **2. PROCESSED library,**this contains saved versions of what numpy array was played through the speaker, and what was recorded via microphone for all the sound files from the WAV library
#
# **3. RAW library,**will contain the raw .xls files of all the wave library files. EDIT: This will now contain the raw-features-tables output by the batching process in SAP-2011, as this will help to automate the process significantly.
#
# Finally, the working directory folder itself may contain the output , ie matlabplots, excel files etc.

# %%
## THIS IS A GREAT STARTING CELL TO RUN TO ENSURE THAT YOU ACTUALLY HAVE THE HARDWARE APPROPRIATELY CONNECTED.
import pysoundcard
print "----------------------------------------------------------------"
print "DEFAULT API: " + str(pysoundcard.default_api())
print "----------------------------------------------------------------"
print "DEFAULT OUTPUT DEVICE: " + str(pysoundcard.default_output_device())
print "----------------------------------------------------------------"
print "DEFAULT INPUT DEVICE: " + str(pysoundcard.default_input_device())
print "----------------------------------------------------------------"

import sys
sys.version
# Out:
# ----------------------------------------------------------------
# DEFAULT API: {'struct_version': 1, 'name': u'MME', 'api_idx': 0, 'type': 2L, 'default_output_device_index': 3, 'device_count': 4, 'default_input_device_index': 1}
# ----------------------------------------------------------------
# DEFAULT OUTPUT DEVICE: {'struct_version': 2, 'input_channels': 0, 'default_high_output_latency': 0.18, 'default_low_output_latency': 0.09, 'default_sample_rate': 44100.0, 'output_latency': 0.09, 'name': u'Speakers (Realtek High Definiti', 'interleaved_data': True, 'default_high_input_latency': 0.18, 'device_index': 3, 'sample_format': <type 'numpy.float32'>, 'default_low_input_latency': 0.09, 'host_api_index': 0, 'input_latency': 0.09, 'output_channels': 2}
# ----------------------------------------------------------------
# DEFAULT INPUT DEVICE: {'struct_version': 2, 'input_channels': 2, 'default_high_output_latency': 0.18, 'default_low_output_latency': 0.09, 'default_sample_rate': 44100.0, 'output_latency': 0.09, 'name': u'Line In (Realtek High Definitio', 'interleaved_data': True, 'default_high_input_latency': 0.18, 'device_index': 1, 'sample_format': <type 'numpy.float32'>, 'default_low_input_latency': 0.09, 'host_api_index': 0, 'input_latency': 0.09, 'output_channels': 0}
# ----------------------------------------------------------------
# '2.7.8 |Anaconda 2.1.0 (64-bit)| (default, Jul  2 2014, 15:12:11) [MSC v.1500 64 bit (AMD64)]'

# %%
## Major dependancies
import numpy as np
from pysoundcard import Stream
import scipy.io.wavfile as wav
from scipy import signal, fftpack # For comparisons
import math
import time
import os
import glob 
import matplotlib.pyplot as plt
#Used for testing at the moment.
# %matplotlib inline 

## CHANGE THIS DEPENDING ON WHAT DIRECTORY YOU WISH TO WORK OUT OF, THIS CAN ALSO BE CHANGED BETWEEN TRIALS BETWEEN HARDWARES etc"
## Note that your working directory should contain 3 folders, RAW_LIB, PROCESSED_LIB, and WAV_LIB
working_directory = "c:\\Users\\mbar372\\Documents\\testing\\hardware_tests\\"

## Update the wav library depending on the working directory.
update_wav_lib(working_directory)

# %%
# Import wav library
wav_data = import_wav_lib(working_directory)

# Play wav library 
iterate_through_all(wav_data, fs = 44100, window = 256)

""" We now go into SAP2011, and use the raw features across and
interval feature to calculate the raw features of all song
characteristics for each .wav file from the Process folder.
The resulting .xml feature libraries are saved in RAW_LIB. Ready to extract.
"""
# Out:
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, ascendingtone.wav. File 1/18
# This will take approximately 31 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 30.0 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30328.9595: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.0009: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.0714: Input overflowed
#   self._handle_error(err)
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.1319: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.1743: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.2435: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.2756: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.3460: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.3484: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.3671: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.3976: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.4288: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.4305: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.4579: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.4595: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.4886: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.5179: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.5195: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.5499: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.5517: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30329.5821: Output underflowed
#   self._handle_error(err)
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30329.5843: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.5995: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.7014: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.7040: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.7059: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.7222: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.7519: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.8231: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.8253: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.8548: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.8564: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.8837: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.8858: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.9148: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.9164: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.9444: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.9465: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.9760: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30329.9780: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.0071: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.0092: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.0269: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30330.0403: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30330.0419: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.0569: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.0868: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.0892: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.1186: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.1204: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.1482: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.1504: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.1693: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.1993: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2010: Input overflowed
#   self._handle_error(err)
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2295: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2314: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2331: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2349: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2365: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2498: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2516: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2613: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2631: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2648: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2666: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.2682: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3013: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3318: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3335: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3352: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3368: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3524: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3546: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3625: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3646: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3667: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3686: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3707: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.3727: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30330.4054: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30330.4075: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.4243: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.4260: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.4279: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.4430: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.5049: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.5254: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.5753: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.6063: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.6871: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.6892: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7076: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7573: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7596: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7624: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7790: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7808: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7881: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7900: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7917: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7936: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7956: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.7975: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8301: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8510: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8612: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8632: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8651: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8670: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8688: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.8707: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9005: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9023: Input overflowed
#   self._handle_error(err)
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9046: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9215: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9232: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9309: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9328: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9346: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9367: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9385: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9405: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9615: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9717: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9741: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9762: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9782: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9805: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30330.9827: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0118: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0141: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0159: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0181: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0328: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0351: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0437: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0462: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0481: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0506: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0526: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.0547: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30331.0874: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.1045: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.1340: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.1358: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.1642: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.1665: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.1683: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.1851: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30331.1975: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30331.1994: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30331.2011: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.2150: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.2168: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.2352: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.2666: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.2960: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.2981: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.3473: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.3781: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.3808: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.3831: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.3973: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.3991: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.4010: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.4480: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.4794: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.4813: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5090: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5107: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5126: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5600: Input overflowed
#   self._handle_error(err)
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5634: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5656: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5821: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5841: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5904: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5923: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5941: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5964: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.5982: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6003: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6022: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6321: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6345: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6364: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6514: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6533: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30331.6551: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6552: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6627: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6645: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6665: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6683: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6701: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.6719: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.7037: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.7230: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.7528: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.7547: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.7847: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.7871: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8044: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8347: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8365: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8648: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8676: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8699: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8858: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.8877: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.9661: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30331.9684: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.0183: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.0202: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.0387: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.0680: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.0699: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.0717: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1202: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1495: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1515: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1533: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1553: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1698: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1716: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1806: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1824: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1843: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1861: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.1879: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2004: Input overflowed
#   self._handle_error(err)
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2032: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2055: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2128: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2151: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2174: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2192: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2213: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2231: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30332.2255: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2255: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2410: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2429: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2512: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2532: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2550: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2573: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2593: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2613: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2919: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2937: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.2957: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3119: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3234: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30332.3252: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3253: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30332.3272: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3273: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30332.3292: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3292: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30332.3312: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3313: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3643: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3938: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.3978: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.4021: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30332.4574: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30332.4597: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.4759: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.4780: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.4945: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5257: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5288: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5311: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5455: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5474: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5493: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5666: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5968: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.5993: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6013: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6178: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6198: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6377: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6675: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6700: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6721: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6884: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.6904: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7384: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7412: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7592: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7612: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7636: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7789: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7809: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30332.7906: Input overflowed
#   self._handle_error(err)
# ...
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3146: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3181: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3217: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.3251: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3252: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.3288: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3288: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3531: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.3578: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3579: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.3621: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3622: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3839: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3874: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3908: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.3945: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4155: Input overflowed
#   self._handle_error(err)
# █
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4194: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4231: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.4264: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4265: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4452: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4491: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4529: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.4569: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4570: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.4609: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4610: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4855: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.4906: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4907: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:641: RuntimeWarning: 30357.4950: Output underflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.4951: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5163: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5199: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5233: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5270: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5446: Input overflowed
#   self._handle_error(err)
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, motif1.wav. File 2/18
# This will take approximately 1 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 0.889297052154 s
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, motif2.wav. File 3/18
# This will take approximately 1 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 0.889297052154 s
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, motif3.wav. File 4/18
# This will take approximately 1 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 0.903424036281 s
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, motif4.wav. File 5/18
# This will take approximately 1 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 0.931632653061 s
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, motif5.wav. File 6/18
# This will take approximately 1 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 0.945759637188 s
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, motif6.wav. File 7/18
# This will take approximately 1 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 0.903401360544 s
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, motif7.wav. File 8/18
# This will take approximately 1 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 0.931655328798 s
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, noise.wav. File 9/18
# This will take approximately 6 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 5.0 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, puretone4000.wav. File 10/18
# This will take approximately 11 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 10.0 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, puretone6000.wav. File 11/18
# This will take approximately 11 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 10.0 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, puretoneC.wav. File 12/18
# This will take approximately 11 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 10.0 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, scales.wav. File 13/18
# This will take approximately 13 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 12.4 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, songbout.wav. File 14/18
# This will take approximately 12 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 11.5678684807 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, songbout_noisex01.wav. File 15/18
# This will take approximately 12 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 11.5678684807 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, songbout_noisex02.wav. File 16/18
# This will take approximately 12 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 11.5678684807 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, songbout_noisex10.wav. File 17/18
# This will take approximately 12 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 11.5678684807 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#  ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Playing sound, songbout_noisex20.wav. File 18/18
# This will take approximately 12 seconds...
# S██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████F - Total Time: 11.5678684807 s
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# ---- ---- ---- ---- -- Done -- ---- ---- ---- ----
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5489: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5525: Input overflowed
#   self._handle_error(err)
# C:\Users\mbar372\AppData\Local\Continuum\Anaconda\lib\site-packages\pysoundcard.py:592: RuntimeWarning: 30357.5566: Input overflowed
#   self._handle_error(err)
# ' We now go into SAP2011, and use the raw features across and\ninterval feature to calculate the raw features of all song\ncharacteristics for each .wav file from the Process folder.\nThe resulting .xml feature libraries are saved in RAW_LIB. Ready to extract.\n'

# %%
# Extract features from saved SAP2011 Raw Feature Files.
#raw_feature_data, raw_recorded_feature_data = import_raw_lib(working_directory)

# Locate the directories to the raw feature and file tables saved from SAP 2011
raw_feature_table = working_directory+ "\\RAW_LIB\\" + "WAV_LIB_RAW.csv"
raw_feature_file_table = working_directory+ "\\RAW_LIB\\" + "WAV_LIB_RAW_FILES.csv"

# Extract the raw feature data as a dictionary
feature_library = load_raw_library(raw_feature_table, raw_feature_file_table)

# %%
print raw_feature_data[0][1].keys()
print raw_feature_data[0][0]
plt.plot(raw_feature_data[0][1]['Amplitude'], lw = 1, c = 'b')

print raw_recorded_feature_data[0][0]
plt.plot(raw_recorded_feature_data[0][1]['Time'], lw = 1, c = 'r')
plt.show()
# Out:
# ['Goodness_of_pitch', 'Wiener_entropy', 'Amplitude', 'Time', 'Peak_frequency', 'Mean_frequency', 'Pitch', 'AM', 'FM']
# rf_songbout_play.xml
# rf_songbout_rec.xml

# %% [markdown]
# I suspect that correlating by the timing infomation ( which I believe is origined at the start of the wav file) might be the most accurate way to get precise alignments. See Below

# %%
"""Testing some output stuff, uses amplitude to set the offset amount,
some of the more highly variable traces like AM and FM especially were difficult
to ensure the correct offset was applied, whereas using amplitude to calculate
the offset is much more robust - the offset for this dataset was 141 samples.
Goodness of pitch, & peak frequency,& Mean_frequency,  came to the same offset conclusion too.

NOTE timing showed acorrelation of 134, as these are linearly ascending values
it is highly likely these could be used as the most robust way to align the data.
"""

test = 'Time'
array_play, array_rec, alignment = create_comparison_arrays(raw_feature_data[0][1][test],raw_recorded_feature_data[0][1][test], draw = "yes", force_align = 0)

a = int(np.corrcoef(array_play,array_rec)[0,1]*1000)/10.0
print str(a) + '% with a alignment of ' + str(alignment) + ' samples.'
# Out:
# 99.9% with a alignment of 134 samples.

# %%
"""
THIS CELL IS A TEST CELL. IGNORE

"""

axes = plt.gca()
axes.set_ylim([-1,1])

play_gain = 10
record_gain = 10

#Just grabs a .wav song file I have on hand. NOTE: From Priscilla's Data, Was recorded with a gain of 30.
fs , wav_data_raw = wav.read("c:\\Users\\mbar372\\Documents\\testing\\hardware_tests\\WAV_LIB\\songbout.wav")

# Angus wrote this in a previous example, It Normalises the sound, When taken away the sound breaches the ability of the speaker,
# And we get clippin issues. This would be due to the PySoundCard expecting Float input. 
# wav_data = np.array(wav_data_raw, dtype=np.float32) # Convert array to ensure it is 32int bit type,
# wav_data /= 2**15 # normalize -max_int16..max_int16 to -1..1

wav_data = pcm2float(wav_data_raw, dtype ='float64')
# Plot the data we are about to play
plt.plot(wav_data)
axes = plt.gca()
axes.set_ylim([-1,1])
print "Number of samples to play: " + str(np.shape(wav_data))
plt.show()

print "Start time:"
# Play the data, and record it too, return the recorded data
new_data = pass_through_hardware(wav_data*play_gain, window = 64)

print "Finished playback!"
# Plot the recorded data, to see what it looks like.
print "Number of samples recorded: " + str(np.shape(new_data))
plt.plot(new_data)
axes = plt.gca()
axes.set_ylim([-1,1])
plt.show()

new_data_raw = new_data
new_data = float2pcm(new_data, dtype ='int16')

plt.show()
wav.write("c:\\Users\\mbar372\\Documents\\testing\\savetest.wav", 44100, new_data)
# Out:
# Number of samples to play: (510143L,)
# Start time:
# S███F - Total Time: 11.5678684807 s
# █
# Finished playback!
# Number of samples recorded: (532131L,)

# %%
array_in = np.array(wav_data, dtype = 'float64')
array_out = np.array(pcm2float(new_data[:len(wav_data)]), dtype = 'float64')


print array_in
print array_out

plt.plot(array_in)
plt.plot(array_out)
plt.show()

#impulse_response = signal.deconvolve(array_out, array_in)
# Out:
# [ 0.99996948  0.99993896  0.99993896 ...,  0.83413696 -0.95761108
#   0.99996948]
# [ 0.99996948  0.          0.         ..., -0.99142456  0.34127808
#   0.41226196]

# %%
plt.plot(wav_data[:20000], c= 'r')
plt.plot(new_data[:20000], c = 'b')
#plt.plot(impulse_response[:20000], c = 'g')
plt.show()

plt.psd(wav_data, Fs = 44100, c= 'r')
plt.psd(new_data, Fs = 44100, c = 'b')
plt.show()


plt.specgram(wav_data, Fs = 44100, NFFT = 512)

plt.show()


plt.specgram(new_data[:len(wav_data)]*100, Fs = 44100, NFFT = 512)
plt.show()

#axes = plt.gca()
#axes.set_xlim([0,10])
#plt.specgram(impulse_response, Fs = 44100, NFFT = 512)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-159d8c9b5108> in <module>()
# ----> 1 plt.plot(wav_data[:20000], c= 'r')
#       2 plt.plot(new_data[:20000], c = 'b')
#       3 #plt.plot(impulse_response[:20000], c = 'g')
#       4 plt.show()
#       5
#
# NameError: name 'plt' is not defined

# %%
new_data_at_50 = new_data

# %%
type(wav_data_raw[0])
# Out:
# numpy.int16

# %%
plt.plot(wav_data_raw)
plt.plot(new_data)

axes = plt.gca()
axes.set_ylim([32767,-32767])

plt.show()

print np.mean(new_data_at_100)
print np.mean(new_data_at_50)
# Out:
# -0.0431964910985
# -0.115382924354

# %% [markdown]
# # METHODS/DEFINITIONS BEYOND THIS POINT (Ensure to initialise them all)

# %%
def iterate_through_all(wav_lib_array, window = 1024, fs = 44100):
    
    """
    This function takes the .wav data loaded from the WAV_LIB folder, and then iterates through each file,
    playing and recording new versions of the sounds. These soudns are saved into another folder, PROCESSED_LIB.
    
    The sound that was just played is also saved, so that both the new files are comparable and created under the same conditions.
    """
    
    # Start on the first wav file, calculate the number of iterations
    i = 0 
    file_count = len(wav_data[:])
    
    # Iterate through each file...
    for i in range(file_count):
        name = wav_data[i][0] # The name of the file
        data = wav_data[i][1] # The raw data of the file
        
        # Here we convert the wav files in FLOAT32 ranged from -1 to 1 for playback
        data = pcm2float(data, dtype='float32')
        print " ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- "
        print "Playing sound, " + name + ". File " + str(i+1) + "/" + str(file_count)
        iterate_length = (len(data)/fs) + 1
        print "This will take approximately " + str(iterate_length) + " seconds... "
        
        
        new_data = pass_through_hardware(data, fs, window) #Play the sound + record it back.
        
        time.sleep(2) # Sleep for 2000 milliseconds, intended to prevent anti-aliasing-like effects on recordings
        #, and provide a short rest period..
        
        # Here we convert BOTH the recorded and played data back to PCM and save them.
        # This way we keep our comparisons consistent in data-type, and they can be read by SAP 2011.
        data = float2pcm(data, dtype = 'int16')
        new_data = float2pcm(new_data, dtype = 'int16')
        
        # Write both the played file AND the recorded files, directly into the PROCESSED folder
        wav.write(working_directory + 'PROCESSED_LIB\\'+name, fs, data)
        wav.write(working_directory + 'PROCESSED_LIB\\recording_'+name, fs, new_data)
        
    print "---- ---- ---- ---- -- Done -- ---- ---- ---- ---- "

# %%
def import_wav_lib(directory): # input is the working directory where 'rawsong' folder is kept
    """ This function returns the normalised amplitude data of all songs in a directory, 
    It also creates another array containing just the names of the files
    """
    directory = directory + "WAV_LIB\\"
    
    ## This is an array of directories to the song files to be tested.
    raw_song_dir_array  = glob.glob(directory + '*.wav')
    ## This cycles through every wav file in the array and assigns its 'data' ( [1] is used to return amplitude data only) to song_array
    song_array = [wav.read(n)[1] for n in raw_song_dir_array]
        
    raw_song_filename_array = os.listdir(directory) #The name of the files  
    
    # We now restructure the two arrays into one dictionary-like array for easy use.
    new_array = (zip(raw_song_filename_array,song_array))
    
    return new_array

# %%
def import_raw_lib(directory): # input is the working directory where 'rawsong' folder is kept
    """ 
    This function takes the output from SAP2011, 
    This output is expected to have two qualities,
    A raw feature .xml file comes in the pair , name_play.xml and name_rec.xml
    All pairs have to exist, else the resulting arrays wont be aligned in pairs.
    
    I may make another method to double check the names match at the start of these
    two outputs, just to ensure that this mismatching pair problem, which
    could occur to human error, doesn't get lost in the code. 
    
    """
    directory = directory + "RAW_LIB\\"
    
    ## This is an array of directories to the song files to be tested.
    raw_feature_dir_array_play  = glob.glob(directory + '*_play.xml')
    raw_feature_dir_array_rec  = glob.glob(directory + '*_rec.xml')
    
    ## This cycles through every raw file in the above array, and extracts its features.
    feature_array_play = [extract_raw_features(n) for n in raw_feature_dir_array_play]
    feature_array_rec = [extract_raw_features(n) for n in raw_feature_dir_array_rec]
    
    # Listdir doesn't allow use of wildcards,  so becuase we are splitting this folder into _play and _rec files, 
    # and I'm too lazy to make two folders, we're gonna do this instead to get the names of the files only using 
    # Glob.glob from earlier.: 
    feature_filename_array_play= [n.rsplit('\\')[-1] for n in raw_feature_dir_array_play]
    feature_filename_array_rec= [n.rsplit('\\')[-1] for n in raw_feature_dir_array_rec]
    
    # We now restructure the two arrays into one dictionary-like array for easy use.
    new_array_play = (zip(feature_filename_array_play,feature_array_play))
    new_array_rec = (zip(feature_filename_array_rec,feature_array_rec))
    
    return new_array_play, new_array_rec

# %%
def update_wav_lib(working_directory):
    
    """ 
    This method simply creates some of the sounds necessary for our analysis and saves them into the WAV_LIB folder for
    later use. It will not create examples of Song, These will need to be added to the WAV_LIB folder at the users descretion
    if they are to be used by the program for playback.
    
    This Only needs to be run a single time to create the appropraite .wav files. 
    Can be re-run if there is a problem with these / they need updating
    
    NOTE. ALL the files are saved as PCM.
    
    """

    fs = 44100
    # Creates a pure tone at Middle C = 261.6 Hz (C4)
    t = np.r_[0:int(fs*10):1] / float(fs)
    fn = 0.2616e3 #middle C
    puretone = np.sin(2 * np.pi * t * fn)/2.0 # Makes the sin at 0.5% power 
    # Converts to PCM
    puretone = float2pcm(puretone, dtype ='int16')
    # Writes to wav file.
    wav.write(working_directory + 'WAV_LIB\\puretoneC.wav',fs, puretone)
    
    # Creates a scale
    t = np.r_[0:int(fs/5):1] / float(fs)
    
    
    fnarray = [130.8,138.6,146.8,155.6,164.8,174.6,185,196,207.7,220,233.1,246.9,
                261.6,277.2,293.7,311.1,329.6,349.2,370,392,415.3,440,466.2,493.9,
                523.3,554.4,587.3,622.3,659.3,698.5,740,784,830.6,880,932.3,987.8,
                1047,1109,1175,1245,1319,1397,1480,1568,1661,1760,1865,1976,
                2093,2217,2349,2489,2637,2794,2960,3136,3322,3520,3729,3951,
                4186] #Starts C3  Ends C8

    multiplier = 1.059479693
    puretone = np.sin(2 * np.pi * t * fnarray[0])/2.0
    
    for n in range(len(fnarray)):
        fn = fnarray[n]
        puretone = np.append(puretone,np.sin(2 * np.pi * t * fn)/2.0) # Makes the sin at 0.5% power 
    # Converts to PCM
    puretone = float2pcm(puretone, dtype ='int16')
    # Writes to wav file.
    wav.write(working_directory + 'WAV_LIB\\scales.wav',fs, puretone)
    
    # Creates a pure tone @ 6000 Hz 
    t = np.r_[0:int(fs*10):1] / float(fs)
    fn = 4000
    puretone = np.sin(2 * np.pi * t * fn)/2.0 # Makes the sin at 0.5% power 
    # Converts to PCM
    puretone = float2pcm(puretone, dtype ='int16')
    # Writes to wav file.
    wav.write(working_directory + 'WAV_LIB\\puretone4000.wav',fs, puretone)

    # Creates ascending tone    
    time_series = np.linspace(0, 10, 44100*10)
    ascendingtone = signal.chirp(time_series, f0=20.0, f1=20000.0, t1=10, method = 'linear')
    ascendingtone = float2pcm(ascendingtone, dtype ='int16')
    wav.write(working_directory + 'WAV_LIB\\ascendingtone.wav',fs, ascendingtone)

    # Creates Noise (5 seconds)
    # values of 0.005 - 0.0005 are typically good values, the higher this value , the more noise.
    noise = np.random.normal(0,0.05,fs * 5)/10
    noise = float2pcm(noise, dtype ='int16')
    wav.write(working_directory + 'WAV_LIB\\noise.wav',fs, noise)

    # Take the fullbout of song, and add noise, save into Wav files.
    fs , wav_data_raw = wav.read(working_directory + 'WAV_LIB\\songbout.wav')
    wav_data = np.array(wav_data_raw, dtype=np.float32)
    wav_data /= 2**15
    
    noise = np.random.normal(0,0.0005,len(wav_data))
    noise_x2 = np.random.normal(0,0.001,len(wav_data))
    noise_x10 = np.random.normal(0,0.005,len(wav_data))
    noise_x20 = np.random.normal(0,0.01,len(wav_data))

    wav_data = wav_data + noise
    wav_data_x2 = wav_data + noise_x2
    wav_data_x10 = wav_data + noise_x10
    wav_data_x20 = wav_data + noise_x20
    
    
    wav_data = float2pcm(wav_data, dtype ='int16')
    wav_data_x2 = float2pcm(wav_data_x2, dtype ='int16')
    wav_data_x10 = float2pcm(wav_data_x10, dtype ='int16')
    wav_data_x20 = float2pcm(wav_data_x20, dtype ='int16')

    wav.write(working_directory + 'WAV_LIB\\songbout_noisex01.wav',fs, wav_data)
    wav.write(working_directory + 'WAV_LIB\\songbout_noisex02.wav',fs, wav_data_x2)
    wav.write(working_directory + 'WAV_LIB\\songbout_noisex10.wav',fs, wav_data_x10)
    wav.write(working_directory + 'WAV_LIB\\songbout_noisex20.wav',fs, wav_data_x20)

# %%
def pass_through_hardware(sound, fs = 44100, window = 1024):
    """
    This definition is designed to take the sound (formated as a single dimensional numpy array) as 
    a first argument, and play it through the default audio device,
    while simultaneously recording from the default recording device. 

    The second argument is the sample rate of the sound, defaults to 44100 Hz
    
    This returns the raw trace of the output/input recording.
    
    window defaults to 1024, to reduce the lag in playback, this should be shorter, such as 32.
    Playback can handle a windowsize of 1
    Recording prefers at least a windowsize of 16
    """
    block_length = window # The size of the sound blocks to be passed to the audio streamer
    output_wav = np.array(1) #Create an empty number array, this will be appended to with the microphone inputs

    # Create the stream instance (An object representing the sound card), and start it.
    s = Stream(sample_rate=fs, block_length=block_length)
    s.start()
    
    #Iterate over the length of the sound to be played with the block size,
    for i in range(len(sound)/block_length):
        # Note the read() and write() functions do not return until the full acquisition or playback is complete
        # This may have led to an issue of recording happening in moments of silence where the playback is complete.
        # This is the likely reason as to why the recordings are slightly offset to the playbacks. Interestingly,
        # The recordings are AHEAD of the playback.. caputuring extra information before playback had started,
        # Additionally , the recording is slightly shorter in total, indicating the possibility of cutting off
        # and not capturing the final moments of the playback. It is likely I will need to incorpate extra lengths of
        # Recording to ensure that the entire playback is captured everytime, with overlap.
        # NOTE, by decreasing the window, we see this effect diminish, which is expected but also impies
        # It is possible this effect is due to the time taken to 'play' the sound, seeming as recording 
        # appears to start before the actual playback. Thus the larger the window of data sent to the
        # Stream (soundcard) the longer it will take to process and play.
                
        # PLAYBACK the next block of sound
        block_to_write = sound[i*block_length:i*block_length+block_length]
        s.write(block_to_write)
        
        # RECORD the next block of sound. Append to new Numpy array.
        new_block = s.read(block_length)[:,0]
        output_wav = np.append(output_wav, new_block)
  
    # Record the next 0.5s of sound (This is handy for addressing the possible undershoot recording problem discussed above)
    new_block = s.read(22050)[:,0]
    output_wav = np.append(output_wav, new_block)
    
    #Stop the stream
    s.stop()
    
    # Return the microphones experiences during sound playback.
    return output_wav

# %%
def quick_play(sound, fs = 44100):
    """
    Helper routine during testing to quickly play a numpy array of data to listen to it.
    """
    block_length = 32 # The size of the sound blocks to be passed to the audio streamer
    s = Stream(sample_rate=fs, block_length=block_length)
    s.start()

    #Iterate over the length of the sound to be played with the block size,
    for i in range(len(sound)/block_length):
        # Play the next block of sound
        s.write(sound[i*block_length:i*block_length+block_length])
        # Record the next block of sound.
        # Prints the time every ~ second , changing block length will cause issues with this due to dtypes.
        # Only included at this time to show progress.
        if (i%(fs/block_length) == 0):
            print (i*1.00/fs)*block_length 
    
    #Stop the stream
    s.stop()

# %%
def extract_raw_features(input_file):
    
    """
    # !!!! SOON TO BE REDUNDANT, REPLACE WITH RAW_FEATURES_TABLE_READER !!!!
    
    This method accepts the directory to a .xml file generated by SAP-2011 that contains the raw features
    of the selected sound from the program. It Extracts the meaningful song feature information from 
    that file, and returns it as a neat dictionary, filled with vectors over time of each song feature,
    all appropraitely labelled.
    
    Note this has been specialised for SAP-2011 .xml files generated in this way. Hence some Hard coding.
    
    Another option would be to make raw_feature_tables using the batching algirithms within SAP 2011.
    These however only carry integer values according to alex, and also I would have to segregate out the 
    wav files within the table, thus I will manually create the raw data using SAP for every wav file.
    """

    import xml.etree.ElementTree as ET
    tree = ET.parse(input_file)
    root = tree.getroot()

    array_of_all_features = []    
    headings_array=[-1] # headings array is added by 1, on purpose. First value is not used.
    
    # Create an array size to iterate over for each heading. 
    # Headings are as follows: (from 0 to 13) 'Time', 'Amplitude', 'Pitch',
    # 'Mean_frequency', 'Peak_frequency', 'Goodness_of_pitch', 'FM', 'AM', 'Wiener_entropy',
    # NOTE: Headings past wiener entropy are disused, and have nul values.
    # 'Continuity_time', 'Continuity_freq', 'Duration_of_state', 'currStartLocation'
    
    for cells in root.iter('colname'):
        headings_array.append(int(cells.attrib['ix']))

    for i in headings_array:
        new_feature_vector = []
        for cells in root.iter('cell'):
            if headings_array[int(cells.attrib['ix'])] == i:
                new_feature_vector.append(float(cells.text))
    
        array_of_all_features.append(new_feature_vector)

    new_dict = {'Time' : array_of_all_features[1],
                'Amplitude' : array_of_all_features[2] ,
                'Pitch' : array_of_all_features[3] ,
                'Mean_frequency' : array_of_all_features[4],  
                'Peak_frequency' : array_of_all_features[5],
                'Goodness_of_pitch' : array_of_all_features[6],
                # x10 to correct decoded units into originals: 0 - 90 degrees 
                'FM' : array_of_all_features[7] * 10 ,
                # x100 to correct into decoded units into originals: 1/t 
                'AM' : array_of_all_features[8]*100,
                # x100 to correct into decoded scale into original scale
                'Wiener_entropy' : array_of_all_features[9]*100}
    
    return new_dict

# %%
"""
We've got this from audio processing github repo, handy for making conversions between datatypes.

https://github.com/mgeier/python-audio/blob/master/audio-files/utility.py

"""

import numpy as np
import contextlib

def float2pcm(sig, dtype='int16'):
    """Convert floating point signal with a range from -1 to 1 to PCM.
    Parameters
    ----------
    sig : array_like
        Input array, must have floating point type.
    dtype : data type, optional
        Desired (integer) data type.
    Returns
    -------
    ndarray
        integer data.
    See Also
    --------
    pcm2float, dtype
    """
    # TODO: allow unsigned (e.g. 8-bit) data

    sig = np.asarray(sig)
    if sig.dtype.kind != 'f':
        raise TypeError("'sig' must be a float array")
    dtype = np.dtype(dtype)
    if dtype.kind != 'i':
        raise TypeError("'dtype' must be signed integer type")

    return (sig * np.iinfo(dtype).max).astype(dtype)

def pcm2float(sig, dtype='float64'):
    """Convert PCM signal to floating point with a range from -1 to 1.
    Use dtype='float32' for single precision.
    Parameters
    ----------
    sig : array_like
        Input array, must have (signed) integral type.
    dtype : data type, optional
        Desired (floating point) data type.
    Returns
    -------
    ndarray
        normalized floating point data.
    See Also
    --------
    float2pcm, dtype
    """
    # TODO: allow unsigned (e.g. 8-bit) data

    sig = np.asarray(sig)
    if sig.dtype.kind != 'i':
        raise TypeError("'sig' must be an array of signed integers")
    dtype = np.dtype(dtype)
    if dtype.kind != 'f':
        raise TypeError("'dtype' must be floating point type")

    # Note that 'min' has a greater (by 1) absolute value than 'max'!
    # Therefore, we use '-min' here to avoid clipping.
    return sig.astype(dtype) / dtype.type(-np.iinfo(sig.dtype).min)

# %%
def create_comparison_arrays(array1,array2, draw = "no", force_align = 0):
    """The purpose of this function is to take two arrays, padd them to the same size, 
    find the point of highest similarity using conjugates in the Fourier plane, 
    and then offset these padded arrays by an amount to create two comparable datasets at a point of highest similarity.
    
    Additionally the user can pass force_align with a sample value, to manually assign an alignment.
    """    
    #sizes and calculate the padding value
    size1 = len(array1)
    size2 = len(array2)
    
    #store original sizes of real data for future use after padding occurs.
    orig_size1 = size1
    orig_size2 = size2
        
    # Calculate padding necesarry to make size1.len = size2.len
    padding_value = abs( size1 - size2 )
   
    #pad the smallest array's end to be the same size as the larger.
    #print "Padding by difference between sizes: " + str(padding_value)
    if size1<size2:
        array1 = np.pad(array1, (0,padding_value), mode = 'constant', constant_values = 0)
    if size2<size1:
        array2 = np.pad(array2, (0,padding_value), mode = 'constant', constant_values = 0)

    # To check lengths are the same still, and update to new values.
    size1 = len(array1)
    size2 = len(array2)
    if size1 != size2:
        #print "Difference between shapes is, " + str(size1) + " and " + str(size2) + "." 
        print "Error, the two arrays failed to pad properly."
    
    ## Here we check, have we been provided with alignment? If no, then calculate one...
    if force_align == 0 : 
        ## Calculate a new offset using FFT
        A = fftpack.fft(array1)
        B = fftpack.fft(array2)
        Ar = -A.conjugate()
        Br = -B.conjugate()
        offset1test = np.argmax(np.abs(fftpack.ifft(Ar*B)))
        offset2test = np.argmax(np.abs(fftpack.ifft(A*Br))) ## This is simply the overshoot of offset1 past the length of the array2
    
    ## Depending on which offset is shorter, depends on which way to move the arrays relative to each other to achieve maximum correlation.
        if offset1test < offset2test:
            offset1 = offset1test
            offset2 = 0
        else:
            offset1 = 0
            offset2 = offset2test
        
    ## Pad by the offset calculated by the correlation onto the beginning of the first array, and onto the end of the second.
    ## Note this is calculated depending on the smallest movement, and is thus applied as either offset 1 or offset 2, but switching
    ## which dataset to add it to the front or back of.
        array1 = np.pad(array1, (int(offset1),int(offset2)), mode = 'constant', constant_values = 0)
        array2 = np.pad(array2, (int(offset2),int(offset1)), mode = 'constant', constant_values = 0)
        
    ## If we have been given an offset to use instead of calculating, use that offset instead of going through calculating our own.
    else:
        offset1 = 0
        offset2 = 0
        if force_align > 0:
            offset1 = force_align
        else:
            force_align < 0
            offset2 = abs(force_align)
        
        array1 = np.pad(array1, (int(offset1),int(offset2)), mode = 'constant', constant_values = 0)
        array2 = np.pad(array2, (int(offset2),int(offset1)), mode = 'constant', constant_values = 0)
        
    # Calculate the points of overlap between the two original arrays, these will be used to clip excess padding.
    point1 = offset1 + offset2
    point2 = min(offset1 + orig_size1, offset2 + orig_size2)
    
    # If draw is yes, then draw the plots to visualise what has occured...
    if draw == 'yes':
        plt.figure(1)
        plt.xlabel('Time')
        plt.ylabel('Frequency')
        plt.subplot(211)
        plt.plot(array1)
        plt.axvline((point1+1), linewidth=2, color='r')
        plt.axvline((point2-1), linewidth=2, color='r')
        plt.subplot(212)
        plt.plot(array2)
        plt.axvline((point1+1), linewidth=2, color='r')
        plt.axvline((point2-1), linewidth=2, color='r')
        plt.show()
    
    comparearray1 = array1[point1:point2]
    comparearray2 = array2[point1:point2]

    # Return only the maximum overlap of the two arrays at the maximum correlation point offset.
    return comparearray1, comparearray2, offset1-offset2

# %%
def load_raw_library(raw_data_table, file_table):
    """
    This function will take the directory of a raw features table, generated by SAP2011, and its corresponding file_table, 
    also generated in SAP2011, and converts them into the fantastic dictionary format where dictionary[filename][songfeature]
    will return the associated data from the raw feature table.
    """
    ####################### STEP 1, extract all raw data from all the files ######################
    # Open the raw data table,
    raw = open(raw_data_table)
    raw = raw.read()
    # TAKE THE DATA FILE AND REPLACE THE FOLLOWING WITH ','
    raw = raw.replace('(','')
    raw = raw.replace(')','')
    raw = raw.replace(' ','')
    raw = raw.replace('\n',',')
    raw = raw.replace(';',',')
    # SPLIT BY ','
    raw = raw.split(',')
    # FORM A NEW ARRAY, CAPTURE ONLY THE DATA (Ints) IN NEW ARRAY
    new_array = []
    for n in range(len(raw)):
        try:
            x = int(raw[n])
        except ValueError:
            ()#print "Found non-int at position ... " + str(n)
        else:
            new_array[n:len(new_array)] = [x]
    # Reshape into columns of song features.
    processed =  np.reshape(new_array,(len(new_array)/14, 14))
    
    ############### STEP 2, extract file names, and assign to file dictionaries #################
    # Extract the file CSV and alter.
    raw_files = open(file_table)
    files = raw_files.read()
    # TAKE THE DATA FILE AND REPLACE THE FOLLOWING WITH ','
    files = files.replace('(','')
    files = files.replace(')','')
    files = files.replace(' ','')
    files = files.replace('\n',',')
    files = files.replace(';',',')
    files = files.replace('\'','')
    # SPLIT BY ','
    files = files.split(',')

    # Extract file name and ID info:
    new_array = []
    for n in range(len(files)):
        try:
            x = int(files[n])
            y = files[n+1]
        except ValueError:
            ()#print "Found non-int at position ... " + str(n)
        else:
            new_array[n:len(new_array)] = [x]
            new_array[n:len(new_array)] = [y]
    file_array =  np.reshape(new_array,(len(new_array)/4, 4))[:,:2]


    new_array = []
    for x in range(len(file_array)):
        #Obtain file ID and name for first file.
        file_id = int(file_array[x,0])
        file_name = file_array[x,1] # This has become redundant.
    
        # Return those data-points in the processed array which match the file ID.
        new_data = processed[np.where(file_id == processed[:,1]),2:][0]
        # Reconstruct into an array of dictionaries of song feature, in an array of song files
        new_dict = {"Amplitude": new_data[:,0], # Db
                "Mean Amplitude Frequency": new_data[:,1],  # Db
                "Pitch": new_data[:,2],  # Hz
                "Mean_frequency": new_data[:,3], # Hz
                "FM": new_data[:,4] * 0.1, # Divide by 10 to turn into Degrees 0-90
                "AM": new_data[:,5] * 0.01, # Divide by 100 to make 1/t
                "Goodness of pitch": new_data[:,6], # nil units
                "Entropy": new_data[:,7]*0.01, # Divide by 100 , no units
                "Peak frequency": new_data[:,8], # Hz
                "DAS": new_data[:,9], # ms
                "Continuity over time": new_data[:,10]*100.0, # Times by 100 to make ms
                "Continuity over frequency": new_data[:,11]*0.01,  # Divide by 100 to make Hz
                }
        # Append the latest dictionary to the song file list
        new_array = np.append(new_array, new_dict)
    
    # Re-assign out the array of song file song feature dictionaries into a final array
    final_array = new_array
    # Create the final dictionary
    file_dict = {file_array[n,1]: final_array[n] for n in range(len(file_array))}

    return file_dict

# %%
def add_percent_bar():
    sys.stdout.write('█') #<-- progress bar meat
    sys.stdout.flush()

# %% [markdown]
# ## IGNORE CELLS BELOW HERE , AS ALL ARE FOR TESTING / CONSTRUCTION ONLY

# %%
quickdir = "C:\\Users\\mbar372\\Documents\\testing\\"
raw = quickdir + "WAV_LIB_RAW.csv"
titles = quickdir + "WAV_LIB_RAW_FILES.csv"

raw_library = load_raw_library(raw,titles)

# %%
for file_name in raw_library:
    for feature_name in raw_library[file_name]:
        print feature_name
# Out:
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency
# Goodness of pitch
# Mean Amplitude Frequency
# Peak frequency
# DAS
# AM
# Amplitude
# Continuity over frequency
# FM
# Continuity over time
# Entropy
# Pitch
# Mean_frequency

# %%
# For testing, go to directory where the SAP files are...
quickdir = "C:\\Users\\mbar372\\Documents\\testing\\"
# READ FILES
raw = open(quickdir + "WAV_LIB_RAW.csv")
# TAKE THE DATA FILE AND REPLACE THE FOLLOWING WITH ','
raw = raw.read()
raw = raw.replace('(','')
raw = raw.replace(')','')
raw = raw.replace(' ','')
raw = raw.replace('\n',',')
raw = raw.replace(';',',')
# SPLIT BY ','
raw = raw.split(',')

# FORM A NEW ARRAY, CAPTURE ONLY THE DATA (Ints) IN NEW ARRAY
new_array = []
print len(raw)
for n in range(len(raw)):
    try:
        x = int(raw[n])
    except ValueError:
        ()#print "Found non-int at position ... " + str(n)
    else:
        new_array[n:len(new_array)] = [x]

print len(new_array)
# Reshape into columns of song features.
processed =  np.reshape(new_array,(len(new_array)/14, 14))

# Print first 10 time points, all features.
print processed[0,:]
# Out:
# 1187114
# 1107568
# [419432780        30       -15       -23       668      1665       643
#         -9        42       -97       861         0         0         0]

# %%
# Extract the file CSV and alter.
raw_files = open(quickdir + "WAV_LIB_RAW_FILES.csv")
files = raw_files.read()

files = files.replace('(','')
files = files.replace(')','')
files = files.replace(' ','')
files = files.replace('\n',',')
files = files.replace(';',',')
files = files.replace('\'','')
# SPLIT BY ','
files = files.split(',')

new_array = []

for n in range(len(files)):
    try:
        x = int(files[n])
        y = files[n+1]
    except ValueError:
        ()#print "Found non-int at position ... " + str(n)
    else:
        new_array[n:len(new_array)] = [x]
        new_array[n:len(new_array)] = [y]

file_array =  np.reshape(new_array,(len(new_array)/4, 4))[:,:2]

new_array = []
for x in range(len(file_array)):
    #Obtain file ID and name for first file.
    file_id = int(file_array[x,0])
    file_name = file_array[x,1]
    
    # Return those data-points in the processed array which match the file ID.
    new_data = processed[np.where(file_id == processed[:,1]),2:][0]
    new_dict = {"Amplitude": new_data[:,0], # Db
                "Mean Amplitude Frequency": new_data[:,1],  # Db
                "Pitch": new_data[:,2],  # Hz
                "Mean_frequency": new_data[:,3], # Hz
                "FM": new_data[:,4] * 0.1, # Divide by 10 to turn into Degrees 0-90
                "AM": new_data[:,5] * 0.01, # Divide by 100 to make 1/t
                "Goodness of pitch": new_data[:,6], # nil units
                "Entropy": new_data[:,7]*0.01, # Divide by 100 , no units
                "Peak frequency": new_data[:,8], # Hz
                "DAS": new_data[:,9], # ms
                "Continuity over time": new_data[:,10]*100.0, # Times by 100 to make ms
                "Continuity over frequency": new_data[:,11]*0.01,  # Divide by 100 to make Hz
                }
    new_array = np.append(new_array, new_dict)
final_array = new_array

file_dict = {file_array[n,1]: final_array[n] for n in range(len(file_array))}

print file_dict.keys()

print file_dict["motif1.wav"].keys()

lets_look_at = 'Pitch'

plt.plot(file_dict["motif1.wav"][lets_look_at])
plt.plot(file_dict["motif2.wav"][lets_look_at])
plt.plot(file_dict["motif3.wav"][lets_look_at])
plt.plot(file_dict["motif4.wav"][lets_look_at])
plt.plot(file_dict["motif5.wav"][lets_look_at])
plt.plot(file_dict["motif6.wav"][lets_look_at])
plt.plot(file_dict["motif7.wav"][lets_look_at])
#plt.show()
# Out:
# ['songbout_noisex20.wav', 'songbout_noisex02.wav', 'noise.wav', 'motif1.wav', 'songbout_noisex01.wav', 'motif3.wav', 'songbout.wav', 'motif5.wav', 'motif4.wav', 'puretone.wav', 'ascendingtone.wav', 'songbout_noisex10.wav', 'motif7.wav', 'motif6.wav', 'motif2.wav']
# ['Goodness of pitch', 'Mean Amplitude Frequency', 'Peak frequency', 'DAS', 'AM', 'Amplitude', 'Continuity over frequency', 'FM', 'Continuity over time', 'Entropy', 'Pitch', 'Mean_frequency']

# %%
print final_array[0]
# Out:
# ["'ascendingtone.wav'"]

# %%
t = zip(processed)

# %%
fs, rawwave = wav.read(working_directory + "WAV_LIB\\songbout.wav")

wave1 = np.array(rawwave, dtype=np.float32)
wave1 /= 2**15 # normalize -max_int16..max_int16 to -1..1

wave2 = pcm2float(rawwave, dtype = 'float32')
plt.plot(rawwave)
plt.show()
plt.plot(wave1)
plt.plot(wave2)
plt.show()

print np.mean(np.subtract(wave1,wave2))

rawwave1 = float2pcm(wave1, dtype = 'int16')
rawwave2 = float2pcm(wave2, dtype = 'int16')

plt.plot(rawwave1)
plt.plot(rawwave2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5b368e053239> in <module>()
# ----> 1 fs, rawwave = wav.read(working_directory + "WAV_LIB\\songbout.wav")
#       2
#       3 wave1 = np.array(rawwave, dtype=np.float32)
#       4 wave1 /= 2**15 # normalize -max_int16..max_int16 to -1..1
#       5
#
# NameError: name 'wav' is not defined
